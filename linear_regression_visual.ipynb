# %%
from numpy import *

import matplotlib.pyplot as plt

def compute_error(b, m, points):
   
    return 1

def stepwise_helper(b_current, m_current, points, learningRate):
    b_gr = 0
    m_gr = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        b_gr += -(2/N) * (y - ((m_current * x) + b_current))
        m_gr += -(2/N) * x * (y - ((m_current * x) + b_current))
    new_b = b_current - (learningRate * b_gr)
    new_m = m_current - (learningRate * m_gr)
     
    return [new_b, new_m]

def fit_fun(points, starting_b, starting_m, learning_rate, num_iterations):
    b = starting_b
    m = starting_m
    for i in range(num_iterations):
        b, m = stepwise_helper(b, m, array(points), learning_rate)
        y=b
        x=(m*70)+b
        x2=[0,70]
        y2=[b,x]
        plt.plot(x2,y2)
    y=b
    x=(m*70)+b
    x3=[0,70]
    y3=[b,x]
    plt.plot(x3,y3, linewidth=2)    
    plt.show()
    return [b, m]

def run():
    points = genfromtxt("datasam1.csv", delimiter=",")
    for i in range(100):
        plt.scatter(points[i][0],points[i][1])
    learning_rate = 0.0001
    initial_b = 0 
    initial_m = 0 
    num_iterations = 1000 
    print("At start b and m are  ",end="")
    print(str(initial_b)+" "+str(initial_m))
    [b, m] = fit_fun(points, initial_b, initial_m, learning_rate, num_iterations)
    print("finally  ",end="")
    
    print(str(b)+" "+str(m))
run()
# Out:
# At start b and m are  0 0
# finally  0.0889365199374 1.47774408519

# %%
import pandas as pd
from numpy import *
# points=pd.read_csv('datasam1.csv')
points = genfromtxt("datasam1.csv", delimiter=",")
print(points[8])
# points[0][0]
# Out:
# [ 48.10504169  75.3312423 ]
