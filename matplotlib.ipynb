# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6,7]
y=[45,56,54,78,64,34,45]
plt.xlabel('Day')
plt.ylabel("temp")
plt.title("graph")
plt.plot(x,y)
plt.show()

# %%
x=[1,2,3,4,5,6,7]
y=[45,56,54,78,64,34,45]
plt.plot(x,y,'g+-.')
plt.grid()
plt.show()

# %%
plt.plot(x,y,'rD')
plt.show()
